# %% [markdown]
# # Covid data

# %%
import sys
sys.path.insert(0, '../')

from minisom import MiniSom
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %%
df = pd.read_csv("base-covid-sinave.csv")
# Out:
# /home/sergio/miniconda3/envs/py3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (84,86,87,88,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   origen sector  cve_entidad_unidad_medica entidad_unidad_medica  \
# 0   USMI    SSA                          9      CIUDAD DE MEXICO
# 1   USMI    SSA                          9      CIUDAD DE MEXICO
# 2   USMI    SSA                          9      CIUDAD DE MEXICO
# 3   USMI    SSA                          9      CIUDAD DE MEXICO
# 4   USMI   IMSS                          9      CIUDAD DE MEXICO
#
#   delegacion_unidad_medica                                      unidad_medica  \
# 0         CIUDAD DE MEXICO  INSTITUTO NACIONAL DE ENFERMEDADES RESPIRATORI...
# 1         CIUDAD DE MEXICO  INSTITUTO NACIONAL DE ENFERMEDADES RESPIRATORI...
# 2         CIUDAD DE MEXICO  INSTITUTO NACIONAL DE ENFERMEDADES RESPIRATORI...
# 3         CIUDAD DE MEXICO  INSTITUTO NACIONAL DE ENFERMEDADES RESPIRATORI...
# 4         CIUDAD DE MEXICO                                HGZMF   8 SAN ANGEL
#
#   fecha_de_registro       sexo entidad_residencia  cve_entidad_residencia  \
# 0        2020-02-25  MASCULINO            HIDALGO                      13
# 1        2020-02-25  MASCULINO   CIUDAD DE MEXICO                       9
# 2        2020-02-25  MASCULINO   CIUDAD DE MEXICO                       9
# 3        2020-02-26  MASCULINO   CIUDAD DE MEXICO                       9
# 4        2020-02-26  MASCULINO   CIUDAD DE MEXICO                       9
#
#   municipio_residencia  cve_municipio_residencia localidad_residencia  \
# 0             TIZAYUCA                      69.0             TIZAYUCA
# 1             COYOACAN                       3.0             COYOACAN
# 2           CUAUHTEMOC                      15.0           CUAUHTEMOC
# 3        BENITO JUAREZ                      14.0        BENITO JUAREZ
# 4       ALVARO OBREGON                      10.0       ALVARO OBREGON
#
#    clave_localidad_residencia  tipo_paciente evolucion_caso fecha_defuncion  \
# 0                         1.0  HOSPITALIZADO      DEFUNCION      2020-02-28
# 1                         1.0  HOSPITALIZADO      DEFUNCION      2020-03-16
# 2                         1.0  HOSPITALIZADO      DEFUNCION      2020-03-09
# 3                         1.0  HOSPITALIZADO      DEFUNCION      2020-03-03
# 4                         1.0  HOSPITALIZADO      DEFUNCION      2020-03-09
#
#    semana_defuncion intubado diagnostico_clinico_neumonia  edad nacionalidad  \
# 0              10.0      NaN                          NaN    23     MEXICANA
# 1              13.0      NaN                          NaN    46     MEXICANA
# 2              12.0      NaN                          NaN    51     MEXICANA
# 3              11.0      NaN                          NaN    27     MEXICANA
# 4              12.0       NO                           NO    35     MEXICANA
#
#   esta_emabarazada  meses_embarazo es_indigena habla_lengua_indigena  \
# 0              NaN             NaN          NO                    NO
# 1              NaN             NaN          NO                    NO
# 2              NaN             NaN          NO                    NO
# 3              NaN             NaN          NO                    NO
# 4               NO             0.0          NO                    NO
#
#                                      ocupacion   servicio_ingreso  \
# 0                                 DESEMPLEADOS  URGENCIAS ADULTOS
# 1  COMERCIANTES DE MERCADOS FIJOS O AMBULANTES  URGENCIAS ADULTOS
# 2                                        OTROS       INFECTOLOGIA
# 3                                  ESTUDIANTES  URGENCIAS ADULTOS
# 4                         OTROS PROFESIONISTAS  URGENCIAS ADULTOS
#
#   fecha_ingreso fecha_inicio_sintomas  \
# 0    2020-02-23            2020-02-13
# 1    2020-02-24            2020-02-22
# 2    2020-02-21            2020-02-06
# 3    2020-02-24            2020-02-23
# 4    2020-02-25            2020-02-24
#
#                         diagnostico_probable fiebre tos odinofagia disnea  \
# 0  INFECCION RESPIRATORIA AGUDA GRAVE (IRAG)     SI  SI         NO     SI
# 1  INFECCION RESPIRATORIA AGUDA GRAVE (IRAG)     SI  SI         NO     SI
# 2  INFECCION RESPIRATORIA AGUDA GRAVE (IRAG)     SI  SI         NO     SI
# 3  INFECCION RESPIRATORIA AGUDA GRAVE (IRAG)     SI  SI         NO     SI
# 4  INFECCION RESPIRATORIA AGUDA GRAVE (IRAG)     SI  SI         NO     SI
#
#   irritabilidad diarrea dolor_toracico calofrios cefalea mialgias artralgias  \
# 0            NO      NO             SI        NO      NO       NO         NO
# 1            SI      SI             SI        NO      SI       SI         SI
# 2            NO      NO             NO        NO      NO       NO         NO
# 3            NO      NO             SI        NO      SI       NO         NO
# 4            SI      SI             SI        SI      SI       NO         NO
#
#   ataque_al_estado_general rinorrea polipnea vomito dolor_abdominal  \
# 0                       NO       NO       NO     NO              NO
# 1                       SI       NO       SI     SI              SI
# 2                       SI       NO       SI     NO              NO
# 3                       SI       NO       NO     NO              NO
# 4                       SI       NO       SI     NO              SI
#
#   conjuntivitis cianosis inicio_subito_sintomas diabetes epoc asma  \
# 0            NO       NO                     SI       NO   NO   NO
# 1            SI       SI                     SI       NO   NO   NO
# 2            NO       NO                     NO       NO   NO   NO
# 3            NO       NO                     SI       NO   NO   NO
# 4            NO       NO                     NO       NO   NO   NO
#
#   inmunosupresivo hipertension VIH_SIDA otra_condicion enfermedad_cardiaca  \
# 0              NO           NO       NO             SI                  NO
# 1              NO           NO       NO             NO                  NO
# 2              NO           NO       SI             NO                  NO
# 3              NO           NO       SI             NO                  NO
# 4              NO           NO       NO             NO                  NO
#
#   obesidad insuficiencia_renal_cronica tabaquismo recibio_tratamiento  \
# 0       NO                          NO         NO                  NO
# 1       NO                          NO         NO                  NO
# 2       NO                          NO         SI                  SI
# 3       NO                          NO         SI                  NO
# 4       NO                          NO         NO                  NO
#
#   recibio_tratamiento_antibiotico recibio_tratamiento_antiviral    antiviral  \
# 0                              SI                            NO          NaN
# 1                              NO                            NO          NaN
# 2                              SI                            NO          NaN
# 3                              SI                            NO          NaN
# 4                             NaN                            SI  OSELTAMIVIR
#
#   fecha_inicio_tratamiento_antiviral contacto_infeccion_viral contacto_aves  \
# 0                                NaN                       NO            NO
# 1                                NaN                       NO            NO
# 2                                NaN                       NO            NO
# 3                                NaN                       NO            NO
# 4                                NaN                      NaN            NO
#
#   contacto_cerdos contacto_animales vacunado fecha_estimada_vacunacion  \
# 0              NO               NaN       NO                       NaN
# 1              NO               NaN       NO                       NaN
# 2              NO               NaN       NO                       NaN
# 3              NO               NaN       NO                       NaN
# 4              NO               NaN       NO                       NaN
#
#   toma_muestra                                       laboratorio  \
# 0           SI  INSTITUTO NACIONAL DE ENFERMEDADES RESPIRATORIAS
# 1           SI  INSTITUTO NACIONAL DE ENFERMEDADES RESPIRATORIAS
# 2           SI  INSTITUTO NACIONAL DE ENFERMEDADES RESPIRATORIAS
# 3           SI  INSTITUTO NACIONAL DE ENFERMEDADES RESPIRATORIAS
# 4           SI                                      IMSS LA RAZA
#
#    folio_laboratorio resultado_definitivo es_migrante pais_nacionalidad  \
# 0                NaN             NEGATIVO         NaN               NaN
# 1                NaN  ENTEROV//RHINOVIRUS         NaN               NaN
# 2                NaN             NEGATIVO         NaN               NaN
# 3                NaN  ENTEROV//RHINOVIRUS         NaN               NaN
# 4                NaN             NEGATIVO         NaN            México
#
#   pais_origen fecha_ingreso_pais puerperio  dias_puerperio antipireticos  \
# 0         NaN                NaN       NaN             NaN           NaN
# 1         NaN                NaN       NaN             NaN           NaN
# 2         NaN                NaN       NaN             NaN           NaN
# 3         NaN                NaN       NaN             NaN           NaN
# 4         NaN                NaN       NaN             NaN            NO
#
#   unidad_cuidados_intensivos linaje_influenza_tipo_b viaje_1 viaje_2 viaje_3  \
# 0                        NaN                     NaN     NaN     NaN     NaN
# 1                        NaN                     NaN     NaN     NaN     NaN
# 2                        NaN                     NaN     NaN     NaN     NaN
# 3                        NaN                     NaN     NaN     NaN     NaN
# 4                         NO                     NaN     NaN     NaN     NaN
#
#   viaje_4 viaje_5 rango_de_edad                     Geo Point  \
# 0     NaN     NaN         21-30                           NaN
# 1     NaN     NaN         41-50  19.3266672536,-99.1503763525
# 2     NaN     NaN         51-60  19.4313734294,-99.1490557562
# 3     NaN     NaN         21-30  19.3806424162,-99.1611346584
# 4     NaN     NaN         31-40    19.336175562,-99.246819712
#
#                                            Geo Shape
# 0                                                NaN
# 1  {"type": "Polygon", "coordinates": [[[-99.1392...
# 2  {"type": "Polygon", "coordinates": [[[-99.1291...
# 3  {"type": "Polygon", "coordinates": [[[-99.1367...
# 4  {"type": "Polygon", "coordinates": [[[-99.1887...

# %%
df.semana_defuncion.describe()
# Out:
# count    11930.000000
# mean        21.868483
# std          2.762342
# min          8.000000
# 25%         20.000000
# 50%         22.000000
# 75%         24.000000
# max         27.000000
# Name: semana_defuncion, dtype: float64
